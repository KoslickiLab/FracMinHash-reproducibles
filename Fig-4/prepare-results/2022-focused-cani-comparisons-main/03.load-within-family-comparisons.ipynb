# %%
import sourmash
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sourmash.picklist import SignaturePicklist
from sourmash.sketchcomparison import FracMinHashComparison

# %%
k21_ani_csv = "gtdb-rs202.family.nucleotide-k21-scaled1000.ani.csv"

# %%
aD = pd.read_csv(k21_ani_csv)
aD
# Out:
#                            comparison     query_name     match_name lca_rank  \
# 0       GCF_002950215_x_GCF_006461405  GCF_002950215  GCF_006461405   family
# 1       GCF_002950215_x_GCF_003064405  GCF_002950215  GCF_003064405   family
# 2       GCF_002950215_x_GCF_013372345  GCF_002950215  GCF_013372345  species
# 3       GCF_002950215_x_GCF_012052805  GCF_002950215  GCF_012052805   family
# 4       GCF_002950215_x_GCF_001246885  GCF_002950215  GCF_001246885   family
# ...                               ...            ...            ...      ...
# 133175  GCA_002779235_x_GCA_002779235  GCA_002779235  GCA_002779235  species
# 133176  GCA_011365055_x_GCA_011365055  GCA_011365055  GCA_011365055  species
# 133177  GCA_011371765_x_GCA_011371765  GCA_011371765  GCA_011371765  species
# 133178  GCA_902384795_x_GCA_902384795  GCA_902384795  GCA_902384795  species
# 133179  GCA_011041895_x_GCA_011041895  GCA_011041895  GCA_011041895  species
#
#                            lca_lineage   avg_ani
# 0                f__Enterobacteriaceae  0.852012
# 1                f__Enterobacteriaceae  0.850500
# 2              s__Escherichia flexneri  0.978173
# 3                f__Enterobacteriaceae  0.854390
# 4                f__Enterobacteriaceae  0.852439
# ...                                ...       ...
# 133175  s__0-14-0-80-44-23 sp002779235  1.000000
# 133176           s__RDOG01 sp011365055  1.000000
# 133177           s__DRVD01 sp011371765  1.000000
# 133178         s__CABMDC01 sp902384795  1.000000
# 133179           s__DRAE01 sp011041895  1.000000
#
# [133180 rows x 6 columns]

# %%
aD['avg_ani'].min()
# Out:
# 0.802945138451643

# %%
# when comparing WITHIN families, minimum ANI is 80%
